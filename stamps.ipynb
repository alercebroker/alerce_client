# %%
import sys
import os

# Ruta alerce_cliente
sys.path.append('/home/alerce/Desktop/alerce/alerce_client')

# %%
from alerce.core import Alerce

alerce = Alerce()

# %%
lsst_oids_mids = {
    "396841690595406": "396841690595406",
    "396841690595409": "396841690595409",
    "396841690595417": "396841690595417",
    "396841724149794": "396841724149794",
    "396841724149795": "396841724149795"
}

ztf_oids_mids = {
    "ZTF25abbgnpr": "3116285370815015013",
    "ZTF25abbgnwe": "3116287730115015008",
    "ZTF25abbgnxy": "3116285375715015019",
    "ZTF25abattig": "3112362714315015011",
    "ZTF25abattjy": "3112363922215015006"     
}

# %% [markdown]
# # LSST

# %%
for oid, mid in lsst_oids_mids.items():
    
    params = {
        "survey_id": "lsst",
        "oid": oid,
        "measurement_id": mid
    }

    stamps = alerce.multisurvey_plot_stamps(**params)
# Out:
#         <div>ZTF oid:396841690595406, measurement_id:396841690595406 </div>
#         <div>&emsp;&emsp;&emsp;&emsp;&emsp;
#         Science
#         &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#         Template
#         &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#         Difference
#         <div class="container">
#             <div style="float:left;width:20%"><img src="http://127.0.0.1:8000/stamp?oid=396841690595406&measurement_id=396841690595406&stamp_type=cutoutScience&file_format=png&survey_id=lsst"></div>
#             <div style="float:left;width:20%"><img src="http://127.0.0.1:8000/stamp?oid=396841690595406&measurement_id=396841690595406&stamp_type=cutoutTemplate&file_format=png&survey_id=lsst"></div>
#             <div style="float:left;width:20%"><img src="http://127.0.0.1:8000/stamp?oid=396841690595406&measurement_id=396841690595406&stamp_type=cutoutDifference&file_format=png&survey_id=lsst"></div>
# ...

# %% [markdown]
# # ZTF

# %%
for oid, mid in ztf_oids_mids.items():
    
    params = {
        "survey_id": "ztf",
        "oid": oid,
        "measurement_id": mid
    }

    stamps = alerce.multisurvey_plot_stamps(**params)
# Out:
#         <div>ZTF oid:ZTF25abbgnpr, measurement_id:3116285370815015013 </div>
#         <div>&emsp;&emsp;&emsp;&emsp;&emsp;
#         Science
#         &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#         Template
#         &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#         Difference
#         <div class="container">
#             <div style="float:left;width:20%"><img src="http://127.0.0.1:8000/stamp?oid=ZTF25abbgnpr&measurement_id=3116285370815015013&stamp_type=cutoutScience&file_format=png&survey_id=ztf"></div>
#             <div style="float:left;width:20%"><img src="http://127.0.0.1:8000/stamp?oid=ZTF25abbgnpr&measurement_id=3116285370815015013&stamp_type=cutoutTemplate&file_format=png&survey_id=ztf"></div>
#             <div style="float:left;width:20%"><img src="http://127.0.0.1:8000/stamp?oid=ZTF25abbgnpr&measurement_id=3116285370815015013&stamp_type=cutoutDifference&file_format=png&survey_id=ztf"></div>
# ...
