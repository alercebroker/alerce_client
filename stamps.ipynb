# %%
import sys
import os

# Ruta alerce_cliente
sys.path.append('/home/alerce/Desktop/alerce/alerce_client')

# %%
from alerce.core import Alerce

alerce = Alerce()

# %% [markdown]
# # LSST

# %% [markdown]
# ## Multi Call

# %%
lsst_oids_mids = {
    "7912941781254205": "8245877210611771",
    "7912941781254183": "8245877210611800",
    "7912941781254281": "8245877210611840",
    "7912941781254247": "8245877210611723",
    "7912941781254224": "8245877210611764"
}

# %%
for oid, mid in lsst_oids_mids.items():
    
    params = {
        "survey_id": "lsst",
        "oid": oid,
        "measurement_id": mid
    }

    stamps = alerce.multisurvey_plot_stamps(**params)
# Out:
#         <div> LSST oid:7912941781254205, measurement_id:8245877210611771 </div>
#         <div>&emsp;&emsp;&emsp;&emsp;&emsp;
#         Science
#         &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#         Template
#         &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#         Difference
#         <div class="container">
#             <div style="float:left;width:20%"><img src="http://54.91.232.147:8009/stamp?oid=7912941781254205&measurement_id=8245877210611771&stamp_type=cutoutScience&file_format=png&survey_id=lsst"></div>
#             <div style="float:left;width:20%"><img src="http://54.91.232.147:8009/stamp?oid=7912941781254205&measurement_id=8245877210611771&stamp_type=cutoutTemplate&file_format=png&survey_id=lsst"></div>
# ...

# %% [markdown]
# ## Single call

# %%
params = {
        "survey_id": "lsst",
        "oid": "7912941781254217",
        "measurement_id": "8245877210611779"
    }

stamps = alerce.multisurvey_plot_stamps(**params)
# Out:
#         <div> LSST oid:7912941781254217, measurement_id:8245877210611779 </div>
#         <div>&emsp;&emsp;&emsp;&emsp;&emsp;
#         Science
#         &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#         Template
#         &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#         Difference
#         <div class="container">
#             <div style="float:left;width:20%"><img src="http://54.91.232.147:8009/stamp?oid=7912941781254217&measurement_id=8245877210611779&stamp_type=cutoutScience&file_format=png&survey_id=lsst"></div>
#             <div style="float:left;width:20%"><img src="http://54.91.232.147:8009/stamp?oid=7912941781254217&measurement_id=8245877210611779&stamp_type=cutoutTemplate&file_format=png&survey_id=lsst"></div>
# ...
